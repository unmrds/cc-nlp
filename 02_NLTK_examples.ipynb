# %%
import nltk
import numpy as np
import matplotlib

# %%
# nltk.download() # use id 'all' to download all
# https://www.nltk.org/book/

# %% [markdown]
# ## Tokenizing
#
# * Start with analyzing a corpus
# * How to build a corpus

# %%
from nltk.tokenize.stanford import StanfordTokenizer
from nltk.tokenize import TweetTokenizer
from nltk import word_tokenize
from nltk.corpus import state_union, stopwords
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
sents()
# Out:
# sent1: Call me Ishmael .
# sent2: The family of Dashwood had long been settled in Sussex .
# sent3: In the beginning God created the heaven and the earth .
# sent4: Fellow - Citizens of the Senate and of the House of Representatives :
# sent5: I have a problem with people PMing me to lol JOIN
# sent6: SCENE 1 : [ wind ] [ clop clop clop ] KING ARTHUR : Whoa there !
# sent7: Pierre Vinken , 61 years old , will join the board as a nonexecutive director Nov. 29 .
# sent8: 25 SEXY MALE , seeks attrac older single lady , for discreet encounters .
# sent9: THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .

# %%
text1.concordance('monstrous')
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text6.concordance('swallow')
# Out:
# Displaying 10 of 10 matches:
#  is a temperate zone . ARTHUR : The swallow may fly south with the sun or the h
# be carried . SOLDIER # 1 : What ? A swallow carrying a coconut ? ARTHUR : It co
# o maintain air - speed velocity , a swallow needs to beat its wings forty - thr
# : It could be carried by an African swallow ! SOLDIER # 1 : Oh , yeah , an Afri
# OLDIER # 1 : Oh , yeah , an African swallow maybe , but not a European swallow
#  swallow maybe , but not a European swallow . That ' s my point . SOLDIER # 2 :
#  and Sir Bedevere , not more than a swallow ' s flight away , had discovered so
# omething . Oh , that ' s an unladen swallow ' s flight , obviously . I mean , t
#  air - speed velocity of an unladen swallow ? ARTHUR : What do you mean ? An Af
# o you mean ? An African or European swallow ? BRIDGEKEEPER : Huh ? I -- I don '

# %%
text1.similar('monstrous')
# Out:
# true contemptible christian abundant few part mean careful puzzled
# mystifying passing curious loving wise doleful gamesome singular
# delightfully perilous fearless

# %%
text2.similar('monstrous')
# Out:
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# a_pretty am_glad a_lucky is_pretty be_glad

# %%
text1.common_contexts(["monstrous", "fearless"])
# Out:
# most_and

# %%
# text5 may be NSFW!

text5.concordance('music')
# Out:
# Displaying 23 of 23 matches:
# ou party hard ..... lol what type of music does your band play the hair ? yep y
# ointed that I look like a soccer mom music out here please what about me U31 ca
# ought I had tuned into Martian swamp music ... hey U55 , good to c u Hello U11
# sts 06. minutes / seconds . it 's my Music . hi JOIN PART JOIN lol maybe he was
# sts 47. minutes / seconds . it 's my Music . Whats going on in this room ? . AC
# hits the floor . reading writing and music specalily love the music JOIN ......
# writing and music specalily love the music JOIN ...... man my spelling sucks to
# y spelling sucks today PART mine too music 's good . dancing 's even better My
# ol me too two left feet ? what kinda music you into ? PART PART rock mostly but
# s30 30. minutes / seconds . it 's my Music . love the playstation ! no way . pc
# sts 56. minutes / seconds . it 's my Music . Lies can be sweet and little . JOI
# ...

# %%
text5.similar('music')
# Out:
# room gay name pm me do you cast girl back place box hear read work
# phone profile bad corner course

# %%
text5.common_contexts(['music', 'read'])
# Out:
# to_and

# %%
from nltk import draw

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America", 'God', 'Union', 'Republic'])

# %%
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
len(text3)
# Out:
# 44764

# %%
set(text3)
# Out:
# {'bear',
#  'unleavened',
#  'Mehujael',
#  'rul',
#  'children',
#  'dress',
#  'pillar',
#  'desire',
#  'Ezer',
#  'token',
#  'aloud',
#  'stayed',
#  'longedst',
#  'both',
#  'Mahalaleel',
#  'knees',
#  'of',
#  'Jabal',
#  'month',
#  'redeemed',
#  'dwell',
#  'nothing',
#  'Hai',
#  'might',
#  'distress',
#  'exchange',
#  'Feed',
#  'battle',
#  'Until',
#  'Hinder',
#  'fig',
#  'enemies',
#  'spi',
#  'broth',
#  'Carmi',
#  'remember',
#  'Shillem',
#  'hadst',
#  'feeble',
#  'Hori',
#  'Malchiel',
#  'lamp',
#  'captain',
#  'Zerah',
#  'despised',
#  'abode',
#  'could',
#  'thy',
#  'hath',
#  'fail',
#  'green',
#  'brook',
#  'fou',
#  'Iscah',
#  'refused',
#  'prospered',
#  'witness',
#  'hast',
#  'Zidon',
#  'fowls',
#  'Male',
#  'binding',
#  'Who',
#  'bak',
#  'received',
#  'grow',
#  'knowledge',
#  'stood',
#  'died',
#  'childless',
#  'creepeth',
#  'feel',
#  'darkness',
#  'Haste',
#  'faces',
#  'summer',
#  'Arphaxad',
#  'breaking',
# ...

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3))
# Out:
# 2789

# %%
len(set(text5)) / len(text5)
# Out:
# 0.13477005109975562

# %%
text3.count('smote')
# Out:
# 5

# %%
100 * text4.count('a') / len(text4)
# Out:
# 1.4643016433938312

# %%
text5.count('lol')
# Out:
# 704

# %%
100 * text5.count('lol') / len(text5)
# Out:
# 1.5640968673628082

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)

# %%
def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(text3)
# Out:
# 0.06230453042623537

# %%
lexical_diversity(text5)
# Out:
# 0.13477005109975562

# %%
percentage(text4.count('a'), len(text4))
# Out:
# 1.4643016433938312

# %%
print(state_union.fileids())
# Out:
# ['1945-Truman.txt', '1946-Truman.txt', '1947-Truman.txt', '1948-Truman.txt', '1949-Truman.txt', '1950-Truman.txt', '1951-Truman.txt', '1953-Eisenhower.txt', '1954-Eisenhower.txt', '1955-Eisenhower.txt', '1956-Eisenhower.txt', '1957-Eisenhower.txt', '1958-Eisenhower.txt', '1959-Eisenhower.txt', '1960-Eisenhower.txt', '1961-Kennedy.txt', '1962-Kennedy.txt', '1963-Johnson.txt', '1963-Kennedy.txt', '1964-Johnson.txt', '1965-Johnson-1.txt', '1965-Johnson-2.txt', '1966-Johnson.txt', '1967-Johnson.txt', '1968-Johnson.txt', '1969-Johnson.txt', '1970-Nixon.txt', '1971-Nixon.txt', '1972-Nixon.txt', '1973-Nixon.txt', '1974-Nixon.txt', '1975-Ford.txt', '1976-Ford.txt', '1977-Ford.txt', '1978-Carter.txt', '1979-Carter.txt', '1980-Carter.txt', '1981-Reagan.txt', '1982-Reagan.txt', '1983-Reagan.txt', '1984-Reagan.txt', '1985-Reagan.txt', '1986-Reagan.txt', '1987-Reagan.txt', '1988-Reagan.txt', '1989-Bush.txt', '1990-Bush.txt', '1991-Bush-1.txt', '1991-Bush-2.txt', '1992-Bush.txt', '1993-Clinton.txt
# ...

# %%
w = state_union.words('1981-Reagan.txt')

# %%
len(w)
# Out:
# 5221

# %%
lexical_diversity(w)
# Out:
# 0.2612526335950967

# %%
w
# Out:
# ['PRESIDENT', 'RONALD', 'REAGAN', "'", 'S', 'ADDRESS', ...]

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text1[173]
# Out:
# 'is'

# %%
w[173]
# Out:
# 'across'

# %%
w.index('across')
# Out:
# 173

# %%
fdist1 = FreqDist(text1)

# %%
print(fdist1)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
fdist1['whale']
# Out:
# 906

# %%
fdist2 = FreqDist(text2)

# %%
print(fdist2)
# Out:
# <FreqDist with 6833 samples and 141576 outcomes>

# %%
fdist2.most_common(50)
# Out:
# [(',', 9397),
#  ('to', 4063),
#  ('.', 3975),
#  ('the', 3861),
#  ('of', 3565),
#  ('and', 3350),
#  ('her', 2436),
#  ('a', 2043),
#  ('I', 2004),
#  ('in', 1904),
#  ('was', 1846),
#  ('it', 1568),
#  ('"', 1506),
#  (';', 1419),
#  ('she', 1333),
#  ('be', 1305),
#  ('that', 1297),
#  ('for', 1234),
#  ('not', 1212),
#  ('as', 1179),
#  ('you', 1037),
#  ('with', 971),
#  ('had', 969),
#  ('his', 941),
#  ('he', 895),
#  ("'", 883),
#  ('have', 807),
#  ('at', 806),
#  ('by', 737),
#  ('is', 728),
#  ('."', 721),
#  ('s', 700),
#  ('Elinor', 684),
#  ('on', 676),
#  ('all', 642),
#  ('him', 633),
#  ('so', 617),
#  ('but', 597),
#  ('which', 592),
#  ('could', 568),
#  ('Marianne', 566),
#  ('my', 551),
#  ('Mrs', 530),
#  ('from', 527),
#  ('would', 507),
#  ('very', 492),
#  ('no', 488),
#  ('their', 463),
#  ('them', 462),
#  ('--', 461)]

# %%
fdist1.plot(50, cumulative=True)

# %%
len(text1)
# Out:
# 260819

# %%
fdist2.plot(50, cumulative=True)

# %%
len(text2)
# Out:
# 141576

# %%
fdist2.hapaxes()
# Out:
# ['Sense',
#  'Sensibility',
#  'Jane',
#  'Austen',
#  '1811',
#  ']',
#  'generations',
#  'inheritor',
#  'bequeath',
#  'Gentleman',
#  'relish',
#  'devolved',
#  'inheriting',
#  'moiety',
#  'bequest',
#  'sale',
#  'articulation',
#  'economically',
#  'tardy',
#  'survived',
#  'including',
#  'legacies',
#  'urgency',
#  'prudently',
#  'caricature',
#  'warmed',
#  'Three',
#  'successively',
#  'funeral',
#  'dispute',
#  'decease',
#  'indelicacy',
#  'keen',
#  'whomsoever',
#  'immoveable',
#  'acutely',
#  'qualified',
#  'counsellor',
#  'joys',
#  'afflicted',
#  'strive',
#  'humored',
#  'imbibed',
#  'romance',
#  'thirteen',
#  '2',
#  'installed',
#  'degraded',
#  'seasons',
#  'alloy',
#  'impoverishing',
#  'headed',
#  'stipulate',
#  'LET',
#  'diminished',
#  'REALLY',
#  'strikes',
#  'Fifteen',
#  'healthy',
#  'clogged',
#  'superannuated',
#  'amazing',
#  'restriction',
#  'drains',
#  'bind',
#  'inconvenient',
#  'enlarge',
#  'sixpence',
# ...

# %%
texts()
# Out:
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
V = set(text4)

# %%
long_words = [w for w in V if len(w) > 15]

# %%
sorted(long_words)
# Out:
# ['RESPONSIBILITIES',
#  'antiphilosophists',
#  'constitutionally',
#  'contradistinction',
#  'discountenancing',
#  'disqualification',
#  'enthusiastically',
#  'instrumentalities',
#  'internationality',
#  'irresponsibility',
#  'misappropriation',
#  'misrepresentation',
#  'misunderstanding',
#  'responsibilities',
#  'sentimentalizing',
#  'transcontinental',
#  'uncharitableness',
#  'unconstitutional']

# %%
fdist4 = FreqDist(text4)

# %%
sorted(w for w in set(text4) if len(w) > 7 and fdist4[w] > 7)
# Out:
# ['Administration',
#  'Almighty',
#  'American',
#  'Americans',
#  'Confederacy',
#  'Congress',
#  'Constitution',
#  'Declaration',
#  'Departments',
#  'European',
#  'Executive',
#  'Government',
#  'Independence',
#  'Jefferson',
#  'Legislature',
#  'Magistrate',
#  'National',
#  'President',
#  'Presidential',
#  'Providence',
#  'Republic',
#  'Revolution',
#  'Southern',
#  'Territories',
#  'Territory',
#  'Treasury',
#  'Washington',
#  'absolute',
#  'accepted',
#  'accomplish',
#  'accomplished',
#  'accordance',
#  'according',
#  'accountability',
#  'achieved',
#  'achievement',
#  'acknowledged',
#  'activities',
#  'additional',
#  'adequate',
#  'adherence',
#  'adjustment',
#  'administer',
#  'administered',
#  'administration',
#  'admitted',
#  'adoption',
#  'advanced',
#  'advancement',
#  'advantage',
#  'advantages',
#  'affecting',
#  'affection',
#  'afforded',
#  'agencies',
#  'aggression',
#  'agitation',
#  'agricultural',
#  'agriculture',
# ...

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations()
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build

# %%
fdist = FreqDist(len(w) for w in text1)

# %%
print(fdist)
# Out:
# <FreqDist with 19 samples and 260819 outcomes>

# %%
fdist.most_common()
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528),
#  (11, 1873),
#  (12, 1053),
#  (13, 567),
#  (14, 177),
#  (15, 70),
#  (16, 22),
#  (17, 12),
#  (18, 1),
#  (20, 1)]

# %%
fdist.plot(20, cumulative=True)

# %%
fdist.freq(3)
# Out:
# 0.19255882431878046

# %%
sorted(w for w in set(text1) if w.endswith('ableness'))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
sorted(w for w in set(text7) if '-' in w and 'index' in w)
# Out:
# ['Stock-index',
#  'index-arbitrage',
#  'index-fund',
#  'index-options',
#  'index-related',
#  'stock-index']

# %%
# lowercase all words in text1
len(set(word.lower() for word in text1))
# Out:
# 17231

# %%
len(set(word.lower() for word in text1 if word.isalpha()))
# Out:
# 16948

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
len(emma)
# Out:
# 192427

# %%
emma = nltk.Text(nltk.corpus.gutenberg.words('austen-emma.txt'))

# %%
emma.concordance("surprize")
# Out:
# Displaying 25 of 37 matches:
# er father , was sometimes taken by surprize at his being still able to pity `
# hem do the other any good ." " You surprize me ! Emma must do Harriet good : a
# Knightley actually looked red with surprize and displeasure , as he stood up ,
# r . Elton , and found to his great surprize , that Mr . Elton was actually on
# d aid ." Emma saw Mrs . Weston ' s surprize , and felt that it must be great ,
# father was quite taken up with the surprize of so sudden a journey , and his f
# y , in all the favouring warmth of surprize and conjecture . She was , moreove
# he appeared , to have her share of surprize , introduction , and pleasure . Th
# ir plans ; and it was an agreeable surprize to her , therefore , to perceive t
# talking aunt had taken me quite by surprize , it must have been the death of m
# f all the dialogue which ensued of surprize , and inquiry , and congratulation
# ...

# %%
emma = gutenberg.words('austen-emma.txt')

# %%
len(gutenberg.raw('austen-emma.txt'))
# Out:
# 887071

# %%
len(gutenberg.words('austen-emma.txt'))
# Out:
# 192427

# %%
len(gutenberg.sents('austen-emma.txt'))
# Out:
# 7752

# %%
len(set(w.lower() for w in gutenberg.words('austen-emma.txt')))
# Out:
# 7344

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']
